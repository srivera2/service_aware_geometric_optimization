# %%
# Top 50 US cities by population with their center coordinates (lat, lon)
TOP_50_CITIES = {
    "New York": (40.7128, -74.0060),
    "Los Angeles": (34.0522, -118.2437),
    "Chicago": (41.8781, -87.6298),
    "Houston": (29.7604, -95.3698),
    "Phoenix": (33.4484, -112.0740),
    "Philadelphia": (39.9526, -75.1652),
    "San Antonio": (29.4241, -98.4936),
    "San Diego": (32.7157, -117.1611),
    "Dallas": (32.7767, -96.7970),
    "San Jose": (37.3382, -121.8863),
    "Austin": (30.2672, -97.7431),
    "Jacksonville": (30.3322, -81.6557),
    "Fort Worth": (32.7555, -97.3308),
    "Columbus": (39.9612, -82.9988),
    "Charlotte": (35.2271, -80.8431),
    "San Francisco": (37.7749, -122.4194),
    "Indianapolis": (39.7684, -86.1581),
    "Seattle": (47.6062, -122.3321),
    "Denver": (39.7392, -104.9903),
    "Washington DC": (38.9072, -77.0369),
    "Boston": (42.3601, -71.0589),
    "El Paso": (31.7619, -106.4850),
    "Nashville": (36.1627, -86.7816),
    "Detroit": (42.3314, -83.0458),
    "Oklahoma City": (35.4676, -97.5164),
    "Portland": (45.5152, -122.6784),
    "Las Vegas": (36.1699, -115.1398),
    "Memphis": (35.1495, -90.0490),
    "Louisville": (38.2527, -85.7585),
    "Baltimore": (39.2904, -76.6122),
    "Milwaukee": (43.0389, -87.9065),
    "Albuquerque": (35.0844, -106.6504),
    "Tucson": (32.2226, -110.9747),
    "Fresno": (36.7378, -119.7871),
    "Mesa": (33.4152, -111.8315),
    "Sacramento": (38.5816, -121.4944),
    "Kansas City": (39.0997, -94.5786),
    "Colorado Springs": (38.8339, -104.8214),
    "Omaha": (41.2565, -95.9345),
    "Raleigh": (35.7796, -78.6382),
    "Miami": (25.7617, -80.1918),
    "Long Beach": (33.7701, -118.1937),
    "Virginia Beach": (36.8529, -75.9780),
    "Oakland": (37.8044, -122.2712),
    "Minneapolis": (44.9778, -93.2650),
    "Tulsa": (36.1540, -95.9928),
    "Tampa": (27.9506, -82.4572),
    "Arlington": (32.7357, -97.1081),
    "New Orleans": (29.9511, -90.0715)
}

# %%
# Import relevant components from Sionna RT
import matplotlib.pyplot as plt
import numpy as np
import mitsuba as mi
import warnings
import sys
import os

from sionna.rt import load_scene, Transmitter, Receiver, Transmitter, Camera, PathSolver, RadioMapSolver
from sionna.rt import AntennaArray, PlanarArray, SceneObject, ITURadioMaterial
from sionna.rt.antenna_pattern import antenna_pattern_registry

# Add the src directory to the Python path
sys.path.append(os.path.abspath('../src'))

# Building placement code
from scene_parser import extract_building_info
from tx_placement import TxPlacement
from boresight_pathsolver import create_zone_mask, optimize_boresight_pathsolver
from angle_utils import azimuth_elevation_to_yaw_pitch
from zone_validator import find_valid_zone

# Running the optimizations on 50 scenes
# These scenes make up the 50 most populous cities in the United States
# Experiment Description (Per Scene):
# Map: 1km x 1 km
# Target: 250m x 250m square zones
# Scenarios: Zone placed 200-400m from TX to ensure multipath propagation
# Frequency: 3.67 GHz
# Tx Placement: Most central building with a 5.0 m offset in Z
# UE Z-Height: 1.5 m
# Initial Orientation: Naive Baseline -> Centroid
# Loss function is single objective: Raise Geometric Mean
# Analysis: RadioMapSolver -> Zone Power per 1x1 meter cell (BEFORE and AFTER optimization)
# Choice of LDS: Sobol, Halton, Latin
# Choice of Sampling Method: Rejection, CDT + Turk's 
# Zone Validation: Ensures high-stakes scenarios (-140 <= p10 <= -80 dBm, p90 >= -130 dBm, range >= 15 dB)

# Get list of scene subdirectories and sort them alphabetically
parent_folder = "../scene/scenes"
scene_dirs = sorted([d for d in os.listdir(parent_folder) if os.path.isdir(os.path.join(parent_folder, d))])

# Dictionary to store all results keyed by scene name
results = {}

# RadioMapSolver()
rm_solver = RadioMapSolver()

# Zone validation thresholds for high-stakes scenarios
validation_thresholds = {
    'p10_min_dbm': -160.0,              # Reject zones with 10th percentile < -200 dBm (too weak/dead)
    'p10_max_dbm': -90.0,               # Reject zones with 10th percentile > -80 dBm (too strong)
    'p90_min_dbm': -105.0,              # Reject zones with 90th percentile < -130 dBm (too weak)
    'min_percentile_range_db': 15.0,    # Require at least 15 dB range between p90 and p10
    'median_max_dbm': -60.0             # I don't want a median that's already too healthy
}

print(f"Testing {len(scene_dirs)} scenes")
print(f"Validation thresholds: {validation_thresholds}\n")

for i, scene_name in enumerate(scene_dirs[:10]):    
    print(f"Scene {i+1}/{len(scene_dirs)}: {scene_name}")
    # Build path to scene XML
    scene_xml_path = os.path.join(parent_folder, scene_name, "scene.xml")
    # Load scene
    scene = load_scene(scene_xml_path)
    
    # Set up the scenario
    # Set the operating frequency (n48 band for 5G)
    scene.frequency = 3.7e9  # 3.7 GHz

    # gNB antenna: 3GPP TR 38.901 pattern (AIRSTRAN D 2200)
    gnb_pattern_factory = antenna_pattern_registry.get("tr38901")
    gnb_pattern = gnb_pattern_factory(polarization="V")

    # UE antenna: Isotropic pattern (typical for mobile devices)
    # This will be required for matching the calculations of the RadioMapSolver()
    ue_pattern_factory = antenna_pattern_registry.get("iso")
    # Polarization should also match the transmitter
    ue_pattern = ue_pattern_factory(polarization="V")

    # SISO: Single antenna element at origin [0, 0, 0] for both TX and RX
    single_element = np.array([[0.0, 0.0, 0.0]])  # Shape: (1, 3)

    # Configure antenna arrays
    scene.tx_array = AntennaArray(
        antenna_pattern=gnb_pattern,
        normalized_positions=single_element.T  # Shape: (3, 1)
    )

    scene.rx_array = AntennaArray(
        antenna_pattern=ue_pattern,
        normalized_positions=single_element.T  # Shape: (3, 1)
    )

    # Disable scattering for basic simulation
    for radio_material in scene.radio_materials.values():
        radio_material.scattering_coefficient = 0.0

    # Select building and establish the transmitter
    building_info = extract_building_info(scene_xml_path, verbose=False)

    # Find the most central building (closest to 0,0)
    min_distance = float('inf')
    selected_building_id = None
    
    for building_id, info in building_info.items():
        x_center, y_center = info['center']
        # Calculate Euclidean distance from (0, 0)
        distance = np.sqrt(x_center**2 + y_center**2)
        if distance < min_distance:
            min_distance = distance
            selected_building_id = building_id
    
    print(f"Selected most central building: {selected_building_id} (distance from origin: {min_distance:.2f}m)")

    # TxPlacement will create the transmitter if it doesn't exist and place it on the building
    # Correct parameter order: (scene, tx_name, scene_xml_path, building_id, offset)
    tx_placer = TxPlacement(scene, "gnb", scene_xml_path, selected_building_id, offset=5.0)
    tx_placer.set_rooftop_center()

    # Get reference to the transmitter (already added to scene by TxPlacement)
    tx = tx_placer.tx
    # Convert to flat numpy array instead of nested list
    gnb_position = tx.position.numpy().flatten().tolist()
    
    print(f"gNB placed on building {selected_building_id} at position: {gnb_position}")  

    # Map Data
    # Define the map configuration
    map_config = {
        'center': [0.0, 0.0, 0.0],
        'size': [1000, 1000],
        'cell_size': (1.0, 1.0),
        'ground_height': 0.0,
    }   

    # Find a valid zone using automatic search with validation
    zone_params_template = {
        'width': 250.0,
        'height': 250.0
    }
    
    zone_mask, zone_stats, zone_center, validation_stats, attempts = find_valid_zone(
        scene=scene,
        tx_name="gnb",
        tx_position=gnb_position,
        map_config=map_config,
        scene_xml_path=scene_xml_path,
        zone_params_template=zone_params_template,
        min_distance=50.0,
        max_distance=300.0,
        max_attempts=200,
        validation_kwargs=validation_thresholds,
        verbose=True
    )
    
    # Check if valid zone was found
    if zone_mask is None:
        print(f"✗ Could not find valid zone for {scene_name} after {attempts} attempts - skipping scene\n")
        results[scene_name] = {
            'status': 'failed',
            'reason': 'No valid zone found',
            'attempts': attempts
        }
        print("="*80 + "\n")
        continue
    
    zone_center_x, zone_center_y = zone_center
    zone_params = zone_stats['zone_params']
    
    print(f"✓ Found valid zone after {attempts} attempt(s)")
    print(f"  Zone center: ({zone_center_x:.1f}, {zone_center_y:.1f})")
    print(f"  P10: {validation_stats['p10_power_dbm']:.1f} dBm, P90: {validation_stats['p90_power_dbm']:.1f} dBm")
    print(f"  Percentile range: {validation_stats['percentile_range_db']:.1f} dB")
    
    # Calculate zone distance and angle from TX for logging
    zone_distance_from_tx = np.sqrt((zone_center_x - gnb_position[0])**2 + (zone_center_y - gnb_position[1])**2)
    zone_angle_from_tx = np.arctan2(zone_center_y - gnb_position[1], zone_center_x - gnb_position[0])

    # Run optimization to get initial and best angles
    best_angles, loss_hist, angle_hist, grad_hist, cov_stats, initial_angles = optimize_boresight_pathsolver(
        scene=scene,
        tx_name="gnb",
        map_config=map_config,
        scene_xml_path=scene_xml_path,
        zone_mask=zone_mask,
        zone_params=zone_params,
        zone_stats=zone_stats,
        num_sample_points=100,
        learning_rate=2.0,
        num_iterations=100,
        verbose=True,
        lds="Latin",
        save_radiomap_frames=False,
        frame_save_interval=10,
        output_dir="./frames/"
    )
    
    print(f"\nOptimization complete!")
    print(f"  Initial angles: Azimuth={initial_angles[0]:.1f}°, Elevation={initial_angles[1]:.1f}°")
    print(f"  Best angles:    Azimuth={best_angles[0]:.1f}°, Elevation={best_angles[1]:.1f}°")

    # ===== EVALUATION WITH INITIAL ANGLES (BASELINE) =====
    print(f"\nEvaluating with INITIAL angles...")
    # Set transmitter orientation to initial angles
    yaw_initial, pitch_initial = azimuth_elevation_to_yaw_pitch(initial_angles[0], initial_angles[1])
    tx.orientation = mi.Point3f(float(yaw_initial), float(pitch_initial), 0.0)
    
    # Generate radio map with initial orientation
    rm_initial = rm_solver(
        scene,
        max_depth=5,
        samples_per_tx=int(6e8),
        cell_size=map_config['cell_size'],
        center=map_config['center'],
        orientation=[0, 0, 0],
        size=map_config['size'],
        los=True,
        specular_reflection=True,
        diffuse_reflection=True,
        diffraction=True,
        edge_diffraction=True,
        refraction=False,
        stop_threshold=None,
    )
    
    # Extract zone power for initial configuration
    rss_watts_initial = rm_initial.rss.numpy()[0, :, :]
    signal_strength_dBm_initial = 10.0 * np.log10(rss_watts_initial + 1e-30) + 30.0
    zone_power_initial = signal_strength_dBm_initial[zone_mask == 1.0]
    
    print(f"  Initial mean power: {np.mean(zone_power_initial):.2f} dBm")

    # ===== EVALUATION WITH OPTIMIZED ANGLES =====
    print(f"Evaluating with OPTIMIZED angles...")
    # Set transmitter orientation to best angles
    yaw_best, pitch_best = azimuth_elevation_to_yaw_pitch(best_angles[0], best_angles[1])
    tx.orientation = mi.Point3f(float(yaw_best), float(pitch_best), 0.0)
    
    # Generate radio map with optimized orientation
    rm_optimized = rm_solver(
        scene,
        max_depth=5,
        samples_per_tx=int(6e8),
        cell_size=map_config['cell_size'],
        center=map_config['center'],
        orientation=[0, 0, 0],
        size=map_config['size'],
        los=True,
        specular_reflection=True,
        diffuse_reflection=True,
        diffraction=True,
        edge_diffraction=True,
        refraction=False,
        stop_threshold=None,
    )
    
    # Extract zone power for optimized configuration
    rss_watts_optimized = rm_optimized.rss.numpy()[0, :, :]
    signal_strength_dBm_optimized = 10.0 * np.log10(rss_watts_optimized + 1e-30) + 30.0
    zone_power_optimized = signal_strength_dBm_optimized[zone_mask == 1.0]
    
    print(f"  Optimized mean power: {np.mean(zone_power_optimized):.2f} dBm")
    print(f"  10th Percentile Improvement: {np.percentile(zone_power_optimized, 10) - np.percentile(zone_power_initial, 10):.2f} dB")
    print(f"  Median Improvement: {np.median(zone_power_optimized) - np.median(zone_power_initial):.2f} dB")

    # Save all relevant data to dictionary
    results[scene_name] = {
        'status': 'success',
        'scene_xml_path': scene_xml_path,
        'map_config': map_config,
        'initial_angles': initial_angles,
        'best_angles': best_angles,
        'loss_hist': loss_hist,
        'angle_hist': angle_hist,
        'grad_hist': grad_hist,
        'cov_stats': cov_stats,
        'tx_building_id': selected_building_id,
        'tx_position': gnb_position,
        'zone_center': [zone_center_x, zone_center_y],
        'zone_distance_from_tx': zone_distance_from_tx,
        'zone_angle_from_tx': zone_angle_from_tx,
        'zone_attempts': attempts,
        'validation_stats': validation_stats,
        'zone_params': zone_params,
        'zone_stats': zone_stats,
        'zone_power_initial': zone_power_initial,
        'zone_power_optimized': zone_power_optimized
    }

    print(f"\nResults saved for {scene_name}")
    print("="*80 + "\n")
# Out:
# Testing 51 scenes
# Validation thresholds: {'p10_min_dbm': -160.0, 'p10_max_dbm': -90.0, 'p90_min_dbm': -105.0, 'min_percentile_range_db': 15.0, 'median_max_dbm': -80.0}
#
# Scene 1/51: Duke
# 2026-02-03 16:41:08 WARN  [HDRFilm] Monochrome mode enabled, setting film output pixel format to 'luminance' (was rgb).
# Selected most central building: 37 (distance from origin: 34.02m)
# gNB placed on building 37 at position: [-23.77073860168457, -24.334800720214844, 15.5]
#
# ======================================================================
# SEARCHING FOR VALID ZONE
# ======================================================================
# Distance range: 50m - 300m from TX
# Max attempts: 200
# ======================================================================
#
# Attempt 1/200:
#   Zone placed at 236.7m, 100.5° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-67.05907440185547, 208.42318725585938, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-67.1, 208.4, 1.5)
# Naive Orientation: Az=100.5°, El=-3.4°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -69.46 dBm
#   Mean Power:       -96.06 dBm
#   90th %ile:        -56.59 dBm
#   Max Power:        -35.51 dBm
#   Std Dev:           65.25 dB
#   P10-P90 Range:    213.41 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-56.6 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=213.4 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 2/200:
#   Zone placed at 299.2m, 289.2° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [74.56991577148438, -306.8819580078125, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (74.6, -306.9, 1.5)
# Naive Orientation: Az=289.2°, El=-2.7°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:    -129.08 dBm
#   Mean Power:      -165.45 dBm
#   90th %ile:        -47.63 dBm
#   Max Power:        -36.93 dBm
#   Std Dev:          101.49 dB
#   P10-P90 Range:    222.37 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-47.6 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=222.4 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 3/200:
#   Zone placed at 289.1m, 348.1° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [259.0785217285156, -84.16661071777344, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (259.1, -84.2, 1.5)
# Naive Orientation: Az=348.1°, El=-2.8°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -72.07 dBm
#   Mean Power:      -125.10 dBm
#   90th %ile:        -52.18 dBm
#   Max Power:        -39.61 dBm
#   Std Dev:           92.01 dB
#   P10-P90 Range:    217.82 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-52.2 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=217.8 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 4/200:
#   Zone placed at 139.9m, 144.0° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-136.90829467773438, 58.008056640625, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-136.9, 58.0, 1.5)
# Naive Orientation: Az=144.0°, El=-5.7°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -69.51 dBm
#   Median Power:     -53.41 dBm
#   Mean Power:       -55.84 dBm
#   90th %ile:        -42.16 dBm
#   Max Power:        -30.58 dBm
#   Std Dev:           18.64 dB
#   P10-P90 Range:     27.35 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-69.5 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-42.2 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=27.3 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -69.5 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 5/200:
#   Zone placed at 226.1m, 51.7° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [116.21851348876953, 153.15625, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (116.2, 153.2, 1.5)
# Naive Orientation: Az=51.7°, El=-3.5°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -84.57 dBm
#   Mean Power:      -133.09 dBm
#   90th %ile:        -42.52 dBm
#   Max Power:        -27.58 dBm
#   Std Dev:           95.17 dB
#   P10-P90 Range:    227.48 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-42.5 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=227.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 6/200:
#   Zone placed at 79.4m, 270.0° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-23.792329788208008, -103.733642578125, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-23.8, -103.7, 1.5)
# Naive Orientation: Az=270.0°, El=-10.0°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -84.64 dBm
#   Median Power:     -54.46 dBm
#   Mean Power:       -65.96 dBm
#   90th %ile:        -33.92 dBm
#   Max Power:        -23.52 dBm
#   Std Dev:           50.46 dB
#   P10-P90 Range:     50.72 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-84.6 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-33.9 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=50.7 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -84.6 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 7/200:
#   Zone placed at 237.6m, 39.2° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [160.4728240966797, 125.76075744628906, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (160.5, 125.8, 1.5)
# Naive Orientation: Az=39.2°, El=-3.4°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:    -106.09 dBm
#   Mean Power:      -165.05 dBm
#   90th %ile:        -55.01 dBm
#   Max Power:        -33.76 dBm
#   Std Dev:           97.38 dB
#   P10-P90 Range:    214.99 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-55.0 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=215.0 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 8/200:
#   Zone placed at 265.4m, 331.5° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [209.531494140625, -150.89547729492188, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (209.5, -150.9, 1.5)
# Naive Orientation: Az=331.5°, El=-3.0°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -61.35 dBm
#   Mean Power:       -83.90 dBm
#   90th %ile:        -41.49 dBm
#   Max Power:        -35.65 dBm
#   Std Dev:           69.31 dB
#   P10-P90 Range:    228.51 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-41.5 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=228.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 9/200:
#   Zone placed at 287.0m, 97.8° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-62.761112213134766, 259.97265625, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-62.8, 260.0, 1.5)
# Naive Orientation: Az=97.8°, El=-2.8°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -75.68 dBm
#   Mean Power:      -127.29 dBm
#   90th %ile:        -61.73 dBm
#   Max Power:        -33.35 dBm
#   Std Dev:           85.93 dB
#   P10-P90 Range:    208.27 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-61.7 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=208.3 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 10/200:
#   Zone placed at 150.3m, 315.0° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [82.53710174560547, -130.53468322753906, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (82.5, -130.5, 1.5)
# Naive Orientation: Az=315.0°, El=-5.3°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -80.65 dBm
#   Median Power:     -50.04 dBm
#   Mean Power:       -65.55 dBm
#   90th %ile:        -35.45 dBm
#   Max Power:        -27.18 dBm
#   Std Dev:           54.55 dB
#   P10-P90 Range:     45.20 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-80.6 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-35.4 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=45.2 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -80.6 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 11/200:
#   Zone placed at 144.5m, 287.2° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [18.943286895751953, -162.33224487304688, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (18.9, -162.3, 1.5)
# Naive Orientation: Az=287.2°, El=-5.5°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -52.28 dBm
#   Mean Power:       -79.49 dBm
#   90th %ile:        -34.22 dBm
#   Max Power:        -24.76 dBm
#   Std Dev:           72.48 dB
#   P10-P90 Range:    235.78 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-34.2 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=235.8 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 12/200:
#   Zone placed at 180.1m, 254.9° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-70.81999969482422, -198.21875, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-70.8, -198.2, 1.5)
# Naive Orientation: Az=254.9°, El=-4.4°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -71.21 dBm
#   Mean Power:      -120.15 dBm
#   90th %ile:        -40.59 dBm
#   Max Power:        -27.56 dBm
#   Std Dev:           94.47 dB
#   P10-P90 Range:    229.41 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-40.6 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=229.4 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 13/200:
#   Zone placed at 276.7m, 127.2° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-191.15318298339844, 196.05043029785156, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-191.2, 196.1, 1.5)
# Naive Orientation: Az=127.2°, El=-2.9°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -65.35 dBm
#   Mean Power:       -94.81 dBm
#   90th %ile:        -46.89 dBm
#   Max Power:        -33.80 dBm
#   Std Dev:           71.66 dB
#   P10-P90 Range:    223.11 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-46.9 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=223.1 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 14/200:
#   Zone placed at 287.6m, 237.7° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-177.43080139160156, -267.4027099609375, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-177.4, -267.4, 1.5)
# Naive Orientation: Az=237.7°, El=-2.8°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:    -270.00 dBm
#   Mean Power:      -206.52 dBm
#   90th %ile:        -69.73 dBm
#   Max Power:        -42.74 dBm
#   Std Dev:           90.62 dB
#   P10-P90 Range:    200.27 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-69.7 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=200.3 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 15/200:
#   Zone placed at 57.8m, 251.6° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-41.9730110168457, -79.2095947265625, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-42.0, -79.2, 1.5)
# Naive Orientation: Az=251.6°, El=-13.6°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -82.52 dBm
#   Median Power:     -53.97 dBm
#   Mean Power:       -65.17 dBm
#   90th %ile:        -35.03 dBm
#   Max Power:        -21.86 dBm
#   Std Dev:           48.45 dB
#   P10-P90 Range:     47.49 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-82.5 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-35.0 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=47.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -82.5 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 16/200:
#   Zone placed at 260.6m, 124.9° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-172.6999053955078, 189.50303649902344, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-172.7, 189.5, 1.5)
# Naive Orientation: Az=124.9°, El=-3.1°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -141.68 dBm
#   Median Power:     -65.26 dBm
#   Mean Power:       -86.36 dBm
#   90th %ile:        -47.20 dBm
#   Max Power:        -34.15 dBm
#   Std Dev:           61.47 dB
#   P10-P90 Range:     94.49 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-141.7 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-47.2 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=94.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 17/200:
#   Zone placed at 126.5m, 77.3° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [4.140174388885498, 99.06179809570312, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (4.1, 99.1, 1.5)
# Naive Orientation: Az=77.3°, El=-6.3°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -101.17 dBm
#   Median Power:     -66.75 dBm
#   Mean Power:       -80.01 dBm
#   90th %ile:        -38.67 dBm
#   Max Power:        -23.41 dBm
#   Std Dev:           57.61 dB
#   P10-P90 Range:     62.50 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-101.2 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-38.7 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=62.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 18/200:
#   Zone placed at 269.4m, 24.3° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [221.83660888671875, 86.35987854003906, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (221.8, 86.4, 1.5)
# Naive Orientation: Az=24.3°, El=-3.0°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:    -270.00 dBm
#   Mean Power:      -186.79 dBm
#   90th %ile:        -68.49 dBm
#   Max Power:        -55.95 dBm
#   Std Dev:           92.21 dB
#   P10-P90 Range:    201.51 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-68.5 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=201.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 19/200:
#   Zone placed at 160.3m, 239.0° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-106.42221069335938, -161.62916564941406, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-106.4, -161.6, 1.5)
# Naive Orientation: Az=239.0°, El=-5.0°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -68.79 dBm
#   Mean Power:      -118.11 dBm
#   90th %ile:        -39.27 dBm
#   Max Power:        -22.68 dBm
#   Std Dev:           94.50 dB
#   P10-P90 Range:    230.73 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-39.3 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=230.7 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 20/200:
#   Zone placed at 272.2m, 65.2° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [90.58393859863281, 222.72183227539062, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (90.6, 222.7, 1.5)
# Naive Orientation: Az=65.2°, El=-2.9°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -79.66 dBm
#   Mean Power:      -133.65 dBm
#   90th %ile:        -49.04 dBm
#   Max Power:        -31.22 dBm
#   Std Dev:           93.33 dB
#   P10-P90 Range:    220.96 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-49.0 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=221.0 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 21/200:
#   Zone placed at 229.6m, 211.1° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-220.38284301757812, -142.867919921875, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-220.4, -142.9, 1.5)
# Naive Orientation: Az=211.1°, El=-3.5°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -94.27 dBm
#   Mean Power:      -158.50 dBm
#   90th %ile:        -52.35 dBm
#   Max Power:        -36.70 dBm
#   Std Dev:          101.10 dB
#   P10-P90 Range:    217.65 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-52.3 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=217.7 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 22/200:
#   Zone placed at 111.7m, 264.9° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-33.738250732421875, -135.56527709960938, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-33.7, -135.6, 1.5)
# Naive Orientation: Az=264.9°, El=-7.1°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -131.66 dBm
#   Median Power:     -56.18 dBm
#   Mean Power:       -76.70 dBm
#   90th %ile:        -34.53 dBm
#   Max Power:        -23.91 dBm
#   Std Dev:           66.12 dB
#   P10-P90 Range:     97.13 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-131.7 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-34.5 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=97.1 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 23/200:
#   Zone placed at 64.5m, 305.3° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [13.467824935913086, -76.98058319091797, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (13.5, -77.0, 1.5)
# Naive Orientation: Az=305.3°, El=-12.2°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -87.00 dBm
#   Median Power:     -51.87 dBm
#   Mean Power:       -62.21 dBm
#   90th %ile:        -34.28 dBm
#   Max Power:        -25.66 dBm
#   Std Dev:           42.48 dB
#   P10-P90 Range:     52.72 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-87.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-34.3 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=52.7 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -87.0 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 24/200:
#   Zone placed at 81.9m, 345.2° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [55.4054069519043, -45.28487014770508, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (55.4, -45.3, 1.5)
# Naive Orientation: Az=345.2°, El=-9.7°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -92.74 dBm
#   Median Power:     -59.27 dBm
#   Mean Power:       -68.16 dBm
#   90th %ile:        -38.95 dBm
#   Max Power:        -29.80 dBm
#   Std Dev:           45.85 dB
#   P10-P90 Range:     53.78 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-92.7 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-39.0 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=53.8 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 25/200:
#   Zone placed at 238.0m, 35.9° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [168.9905548095703, 115.23867797851562, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (169.0, 115.2, 1.5)
# Naive Orientation: Az=35.9°, El=-3.4°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:    -126.77 dBm
#   Mean Power:      -173.78 dBm
#   90th %ile:        -62.78 dBm
#   Max Power:        -34.44 dBm
#   Std Dev:           95.81 dB
#   P10-P90 Range:    207.22 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-62.8 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=207.2 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 26/200:
#   Zone placed at 98.4m, 239.7° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-73.47014617919922, -109.26715087890625, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-73.5, -109.3, 1.5)
# Naive Orientation: Az=239.7°, El=-8.1°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -58.17 dBm
#   Mean Power:       -80.77 dBm
#   90th %ile:        -37.78 dBm
#   Max Power:        -22.20 dBm
#   Std Dev:           69.76 dB
#   P10-P90 Range:    232.22 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-37.8 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=232.2 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 27/200:
#   Zone placed at 224.3m, 42.4° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [141.93580627441406, 126.87167358398438, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (141.9, 126.9, 1.5)
# Naive Orientation: Az=42.4°, El=-3.6°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -94.72 dBm
#   Mean Power:      -150.48 dBm
#   90th %ile:        -44.92 dBm
#   Max Power:        -30.55 dBm
#   Std Dev:           97.18 dB
#   P10-P90 Range:    225.08 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-44.9 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=225.1 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 28/200:
#   Zone placed at 79.0m, 293.4° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [7.549317359924316, -96.8255386352539, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (7.5, -96.8, 1.5)
# Naive Orientation: Az=293.4°, El=-10.1°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -85.75 dBm
#   Median Power:     -51.10 dBm
#   Mean Power:       -62.95 dBm
#   90th %ile:        -33.84 dBm
#   Max Power:        -24.62 dBm
#   Std Dev:           45.95 dB
#   P10-P90 Range:     51.91 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-85.7 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-33.8 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=51.9 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -85.7 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 29/200:
#   Zone placed at 84.7m, 332.4° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [51.27067184448242, -63.635986328125, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (51.3, -63.6, 1.5)
# Naive Orientation: Az=332.4°, El=-9.4°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -89.60 dBm
#   Median Power:     -54.78 dBm
#   Mean Power:       -65.81 dBm
#   90th %ile:        -37.07 dBm
#   Max Power:        -29.26 dBm
#   Std Dev:           48.40 dB
#   P10-P90 Range:     52.53 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-89.6 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-37.1 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=52.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -89.6 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 30/200:
#   Zone placed at 74.5m, 140.4° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-81.17741394042969, 23.180469512939453, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-81.2, 23.2, 1.5)
# Naive Orientation: Az=140.4°, El=-10.6°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -69.80 dBm
#   Median Power:     -54.37 dBm
#   Mean Power:       -56.02 dBm
#   90th %ile:        -42.01 dBm
#   Max Power:        -28.82 dBm
#   Std Dev:           13.83 dB
#   P10-P90 Range:     27.79 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-69.8 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-42.0 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=27.8 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -69.8 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 31/200:
#   Zone placed at 167.6m, 288.1° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [28.338123321533203, -183.6038360595703, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (28.3, -183.6, 1.5)
# Naive Orientation: Az=288.1°, El=-4.8°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -55.41 dBm
#   Mean Power:       -88.68 dBm
#   90th %ile:        -34.82 dBm
#   Max Power:        -26.25 dBm
#   Std Dev:           81.10 dB
#   P10-P90 Range:    235.18 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-34.8 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=235.2 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 32/200:
#   Zone placed at 236.9m, 325.3° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [171.05992126464844, -159.1162109375, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (171.1, -159.1, 1.5)
# Naive Orientation: Az=325.3°, El=-3.4°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -134.26 dBm
#   Median Power:     -55.45 dBm
#   Mean Power:       -78.06 dBm
#   90th %ile:        -39.50 dBm
#   Max Power:        -31.20 dBm
#   Std Dev:           65.31 dB
#   P10-P90 Range:     94.75 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-134.3 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-39.5 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=94.8 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 33/200:
#   Zone placed at 140.1m, 107.8° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-66.7019271850586, 109.01136016845703, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-66.7, 109.0, 1.5)
# Naive Orientation: Az=107.8°, El=-5.7°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -74.42 dBm
#   Median Power:     -60.10 dBm
#   Mean Power:       -63.80 dBm
#   90th %ile:        -42.95 dBm
#   Max Power:        -24.20 dBm
#   Std Dev:           30.04 dB
#   P10-P90 Range:     31.47 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-74.4 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-42.9 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=31.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -74.4 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 34/200:
#   Zone placed at 67.5m, 264.5° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-30.224069595336914, -91.480712890625, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-30.2, -91.5, 1.5)
# Naive Orientation: Az=264.5°, El=-11.7°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -83.55 dBm
#   Median Power:     -54.27 dBm
#   Mean Power:       -64.78 dBm
#   90th %ile:        -33.95 dBm
#   Max Power:        -23.23 dBm
#   Std Dev:           48.02 dB
#   P10-P90 Range:     49.59 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-83.5 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-34.0 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=49.6 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -83.5 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 35/200:
#   Zone placed at 224.3m, 341.8° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [189.24777221679688, -94.50786590576172, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (189.2, -94.5, 1.5)
# Naive Orientation: Az=341.8°, El=-3.6°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -66.39 dBm
#   Mean Power:       -94.66 dBm
#   90th %ile:        -41.80 dBm
#   Max Power:        -34.63 dBm
#   Std Dev:           76.48 dB
#   P10-P90 Range:    228.20 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-41.8 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=228.2 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 36/200:
#   Zone placed at 274.1m, 328.4° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [209.60316467285156, -168.1682891845703, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (209.6, -168.2, 1.5)
# Naive Orientation: Az=328.4°, El=-2.9°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -57.41 dBm
#   Mean Power:       -83.01 dBm
#   90th %ile:        -41.27 dBm
#   Max Power:        -35.56 dBm
#   Std Dev:           69.36 dB
#   P10-P90 Range:    228.73 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-41.3 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=228.7 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 37/200:
#   Zone placed at 153.9m, 134.0° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-130.70697021484375, 86.37312316894531, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-130.7, 86.4, 1.5)
# Naive Orientation: Az=134.0°, El=-5.2°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -71.63 dBm
#   Median Power:     -55.12 dBm
#   Mean Power:       -58.33 dBm
#   90th %ile:        -42.82 dBm
#   Max Power:        -28.27 dBm
#   Std Dev:           22.57 dB
#   P10-P90 Range:     28.81 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-71.6 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-42.8 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=28.8 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -71.6 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 38/200:
#   Zone placed at 231.4m, 307.5° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [117.22830200195312, -207.78273010253906, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (117.2, -207.8, 1.5)
# Naive Orientation: Az=307.5°, El=-3.5°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -52.21 dBm
#   Mean Power:       -86.82 dBm
#   90th %ile:        -37.29 dBm
#   Max Power:        -30.31 dBm
#   Std Dev:           78.67 dB
#   P10-P90 Range:    232.71 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-37.3 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=232.7 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 39/200:
#   Zone placed at 151.4m, 30.6° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [106.56211853027344, 52.773155212402344, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (106.6, 52.8, 1.5)
# Naive Orientation: Az=30.6°, El=-5.3°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -76.70 dBm
#   Mean Power:      -118.16 dBm
#   90th %ile:        -41.69 dBm
#   Max Power:        -23.46 dBm
#   Std Dev:           86.78 dB
#   P10-P90 Range:    228.31 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-41.7 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=228.3 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 40/200:
#   Zone placed at 248.7m, 268.3° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [-31.03989601135254, -272.902587890625, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (-31.0, -272.9, 1.5)
# Naive Orientation: Az=268.3°, El=-3.2°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -97.14 dBm
#   Mean Power:      -158.89 dBm
#   90th %ile:        -52.54 dBm
#   Max Power:        -37.27 dBm
#   Std Dev:          100.94 dB
#   P10-P90 Range:    217.46 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-52.5 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=217.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 41/200:
#   Zone placed at 86.1m, 293.8° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [-23.77073860168457, -24.334800720214844, 15.5]
# look_at_position: [10.973043441772461, -103.08380126953125, 1.5]
# TX Position: (-23.8, -24.3, 15.5)
# Zone Center: (11.0, -103.1, 1.5)
# Naive Orientation: Az=293.8°, El=-9.2°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -86.07 dBm
#   Median Power:     -51.00 dBm
#   Mean Power:       -63.60 dBm
# ...
# ======================================================================
#
# Attempt 57/200:
#   Zone placed at 90.6m, 96.6° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [13.826434135437012, 119.67063903808594, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (13.8, 119.7, 1.5)
# Naive Orientation: Az=96.6°, El=-27.2°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -112.68 dBm
#   Median Power:     -65.92 dBm
#   Mean Power:       -84.41 dBm
#   90th %ile:        -54.11 dBm
#   Max Power:        -38.51 dBm
#   Std Dev:           55.27 dB
#   P10-P90 Range:     58.57 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-112.7 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-54.1 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=58.6 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 58/200:
#   Zone placed at 100.0m, 12.4° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [121.93387603759766, 51.16410827636719, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (121.9, 51.2, 1.5)
# Naive Orientation: Az=12.4°, El=-24.9°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -98.64 dBm
#   Median Power:     -58.40 dBm
#   Mean Power:       -74.21 dBm
#   90th %ile:        -40.74 dBm
#   Max Power:        -31.62 dBm
#   Std Dev:           54.40 dB
#   P10-P90 Range:     57.91 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-98.6 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-40.7 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=57.9 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 59/200:
#   Zone placed at 188.4m, 297.4° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [110.92620849609375, -137.5486297607422, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (110.9, -137.5, 1.5)
# Naive Orientation: Az=297.4°, El=-13.9°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -96.61 dBm
#   Median Power:     -61.44 dBm
#   Mean Power:       -78.15 dBm
#   90th %ile:        -44.13 dBm
#   Max Power:        -33.76 dBm
#   Std Dev:           54.95 dB
#   P10-P90 Range:     52.48 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-96.6 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-44.1 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=52.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 60/200:
#   Zone placed at 215.8m, 231.1° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [-111.27053833007812, -138.2158203125, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (-111.3, -138.2, 1.5)
# Naive Orientation: Az=231.1°, El=-12.2°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -270.00 dBm
#   Median Power:     -62.95 dBm
#   Mean Power:       -98.68 dBm
#   90th %ile:        -48.84 dBm
#   Max Power:        -35.73 dBm
#   Std Dev:           79.49 dB
#   P10-P90 Range:    221.17 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-270.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-48.8 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=221.2 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too weak: -270.0 dBm < -160.0 dBm threshold
# ======================================================================
#
# Attempt 61/200:
#   Zone placed at 163.5m, 112.8° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [-38.97760009765625, 180.52352905273438, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (-39.0, 180.5, 1.5)
# Naive Orientation: Az=112.8°, El=-15.9°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -138.16 dBm
#   Median Power:     -66.81 dBm
#   Mean Power:       -85.56 dBm
#   90th %ile:        -44.65 dBm
#   Max Power:        -39.40 dBm
#   Std Dev:           61.32 dB
#   P10-P90 Range:     93.51 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-138.2 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-44.7 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=93.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 62/200:
#   Zone placed at 98.6m, 20.2° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [116.8406753540039, 63.74493408203125, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (116.8, 63.7, 1.5)
# Naive Orientation: Az=20.2°, El=-25.2°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -99.99 dBm
#   Median Power:     -58.52 dBm
#   Mean Power:       -75.25 dBm
#   90th %ile:        -41.65 dBm
#   Max Power:        -31.73 dBm
#   Std Dev:           54.82 dB
#   P10-P90 Range:     58.34 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-100.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-41.7 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=58.3 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 63/200:
#   Zone placed at 140.8m, 154.2° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [-102.51185607910156, 90.87732696533203, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (-102.5, 90.9, 1.5)
# Naive Orientation: Az=154.2°, El=-18.3°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -117.71 dBm
#   Median Power:     -70.08 dBm
#   Mean Power:       -85.57 dBm
#   90th %ile:        -44.96 dBm
#   Max Power:        -36.04 dBm
#   Std Dev:           60.28 dB
#   P10-P90 Range:     72.74 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-117.7 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-45.0 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=72.7 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 64/200:
#   Zone placed at 161.6m, 50.7° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [126.54835510253906, 154.87454223632812, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (126.5, 154.9, 1.5)
# Naive Orientation: Az=50.7°, El=-16.1°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -113.96 dBm
#   Median Power:     -59.50 dBm
#   Mean Power:       -82.47 dBm
#   90th %ile:        -47.44 dBm
#   Max Power:        -35.60 dBm
#   Std Dev:           61.59 dB
#   P10-P90 Range:     66.52 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-114.0 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-47.4 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=66.5 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 65/200:
#   Zone placed at 92.3m, 58.4° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [72.64727783203125, 108.3032455444336, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (72.6, 108.3, 1.5)
# Naive Orientation: Az=58.4°, El=-26.7°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -99.23 dBm
#   Median Power:     -61.16 dBm
#   Mean Power:       -77.85 dBm
#   90th %ile:        -49.40 dBm
#   Max Power:        -34.06 dBm
#   Std Dev:           51.70 dB
#   P10-P90 Range:     49.82 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-99.2 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-49.4 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=49.8 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 66/200:
#   Zone placed at 223.2m, 262.3° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [-5.614920139312744, -191.47959899902344, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (-5.6, -191.5, 1.5)
# Naive Orientation: Az=262.3°, El=-11.8°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -89.06 dBm
#   Median Power:     -56.80 dBm
#   Mean Power:       -69.79 dBm
#   90th %ile:        -44.16 dBm
#   Max Power:        -33.50 dBm
#   Std Dev:           45.04 dB
#   P10-P90 Range:     44.91 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-89.1 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-44.2 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=44.9 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -89.1 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 67/200:
#   Zone placed at 137.3m, 185.4° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [-112.39456176757812, 16.785781860351562, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (-112.4, 16.8, 1.5)
# Naive Orientation: Az=185.4°, El=-18.7°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:       -101.42 dBm
#   Median Power:     -62.75 dBm
#   Mean Power:       -80.00 dBm
#   90th %ile:        -45.01 dBm
#   Max Power:        -33.59 dBm
#   Std Dev:           58.58 dB
#   P10-P90 Range:     56.41 dB
#
# Validation Checks:
#   P10 Range:      ✓ PASS (p10=-101.4 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-45.0 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=56.4 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: Median is greater than -80.0 dBm
# ======================================================================
#
# Attempt 68/200:
#   Zone placed at 248.8m, 259.3° from TX
#
# ======================================================================
# ZONE VALIDATION
# ======================================================================
# Tx Position: [24.269153594970703, 29.720279693603516, 48.0]
# look_at_position: [-22.107410430908203, -214.7163848876953, 1.5]
# TX Position: (24.3, 29.7, 48.0)
# Zone Center: (-22.1, -214.7, 1.5)
# Naive Orientation: Az=259.3°, El=-10.6°
#
# Running quick coverage check...
#
# Coverage Statistics:
#   Min Power:       -270.00 dBm
#   10th %ile:        -82.74 dBm
#   Median Power:     -56.36 dBm
#   Mean Power:       -65.30 dBm
#   90th %ile:        -44.09 dBm
#   Max Power:        -33.76 dBm
#   Std Dev:           36.23 dB
#   P10-P90 Range:     38.65 dB
#
# Validation Checks:
#   P10 Range:      ✗ FAIL (p10=-82.7 dBm, range=[-160.0, -90.0] dBm)
#   P90 Threshold:  ✓ PASS (p90=-44.1 dBm, min=-105.0 dBm)
#   Percentile Range: ✓ PASS (range=38.7 dB, min=15.0 dB)
#
# ======================================================================
# ✗ ZONE REJECTED: 10th percentile too strong: -82.7 dBm > -90.0 dBm threshold
# ======================================================================
#
# Attempt 69/200:
#   Zone placed at 298.9m, 62.8° from TX
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 144
#     138 # Find a valid zone using automatic search with validation
#     139 zone_params_template = {
#     140     'width': 250.0,
#     141     'height': 250.0
#     142 }
# --> 144 zone_mask, zone_stats, zone_center, validation_stats, attempts = find_valid_zone(
#     145     scene=scene,
#     146     tx_name="gnb",
#     147     tx_position=gnb_position,
#     148     map_config=map_config,
#     149     scene_xml_path=scene_xml_path,
#     150     zone_params_template=zone_params_template,
#     151     min_distance=50.0,
#     152     max_distance=300.0,
#     153     max_attempts=200,
#     154     validation_kwargs=validation_thresholds,
#     155     verbose=True
#     156 )
#     158 # Check if valid zone was found
#     159 if zone_mask is None:
#
# File ~/service_aware_geometric_optimization/src/zone_validator.py:313, in find_valid_zone(scene, tx_name, tx_position, map_config, scene_xml_path, zone_params_template, min_distance, max_distance, max_attempts, validation_kwargs, verbose)
#     311 # Create zone mask
#     312 try:
# --> 313     zone_mask, naive_look_at, zone_stats = create_zone_mask(
#     314         map_config=map_config,
#     315         zone_type='box',
#     316         origin_point=tx_position,
#     317         zone_params=zone_params,
#     318         target_height=1.5,
#     319         scene_xml_path=scene_xml_path,
#     320         exclude_buildings=True
#     321     )
#     322 except ValueError as e:
#     323     if verbose:
#
# File ~/service_aware_geometric_optimization/src/boresight_pathsolver.py:425, in create_zone_mask(map_config, zone_type, origin_point, zone_params, target_height, scene_xml_path, exclude_buildings)
#     420     raise ValueError(
#     421         f"Box width and height must be positive, got width={bw}, height={bh}"
#     422     )
#     424 # Create box mask
# --> 425 in_x = np.abs(X - bx) <= (bw / 2)
#     426 in_y = np.abs(Y - by) <= (bh / 2)
#     427 in_box = in_x & in_y
#
# KeyboardInterrupt:

# %%
# Post-processing analysis: Compare INITIAL vs OPTIMIZED performance
# Calculate improvement statistics across all successful scenes

print("="*80)
print("COVERAGE IMPROVEMENT ANALYSIS")
print("="*80)

# Filter results to only include successful optimizations
successful_results = {k: v for k, v in results.items() if v.get('status') == 'success'}
failed_results = {k: v for k, v in results.items() if v.get('status') == 'failed'}

print(f"\nTotal scenes: {len(results)}")
print(f"Successful optimizations: {len(successful_results)}")
print(f"Failed to find valid zone: {len(failed_results)}")

if failed_results:
    print("\nFailed scenes:")
    for scene_name, data in failed_results.items():
        print(f"  - {scene_name}: {data.get('reason')} ({data.get('attempts')} attempts)")

print("\n" + "="*80)

if len(successful_results) == 0:
    print("No successful optimizations to analyze!")
    print("="*80)
else:
    # ===== Per-Scene Statistics (Initial vs Optimized) =====
    print("\nCalculating per-zone statistics (Initial vs Optimized)...")
    print("="*80)

    improvement_summary = []

    for scene_name, data in successful_results.items():
        zone_power_initial = data['zone_power_initial']
        zone_power_optimized = data['zone_power_optimized']
        
        # Calculate statistics for INITIAL configuration
        stats_initial = {
            'mean_power': np.mean(zone_power_initial),
            'median_power': np.median(zone_power_initial),
            'percentile_10': np.percentile(zone_power_initial, 10),
            'percentile_90': np.percentile(zone_power_initial, 90),
            'std_dev': np.std(zone_power_initial),
            'num_cells': len(zone_power_initial)
        }
        
        # Calculate statistics for OPTIMIZED configuration
        stats_optimized = {
            'mean_power': np.mean(zone_power_optimized),
            'median_power': np.median(zone_power_optimized),
            'percentile_10': np.percentile(zone_power_optimized, 10),
            'percentile_90': np.percentile(zone_power_optimized, 90),
            'std_dev': np.std(zone_power_optimized),
            'num_cells': len(zone_power_optimized)
        }
        
        # Calculate improvements
        improvement = {
            'scene_name': scene_name,
            'mean_improvement_dB': stats_optimized['mean_power'] - stats_initial['mean_power'],
            'median_improvement_dB': stats_optimized['median_power'] - stats_initial['median_power'],
            'p10_improvement_dB': stats_optimized['percentile_10'] - stats_initial['percentile_10'],
            'p90_improvement_dB': stats_optimized['percentile_90'] - stats_initial['percentile_90'],
            'std_dev_change_dB': stats_optimized['std_dev'] - stats_initial['std_dev']
        }
        improvement_summary.append(improvement)
        
        # Store statistics back in results dictionary
        results[scene_name]['stats_initial'] = stats_initial
        results[scene_name]['stats_optimized'] = stats_optimized
        results[scene_name]['improvement'] = improvement
        
        # Print per-scene summary
        print(f"\n{scene_name}:")
        print(f"  INITIAL  - Mean: {stats_initial['mean_power']:>7.2f} dBm, Median: {stats_initial['median_power']:>7.2f} dBm")
        print(f"  OPTIMIZED- Mean: {stats_optimized['mean_power']:>7.2f} dBm, Median: {stats_optimized['median_power']:>7.2f} dBm")
        print(f"  IMPROVEMENT: {improvement['mean_improvement_dB']:>+6.2f} dB (mean), {improvement['median_improvement_dB']:>+6.2f} dB (median)")

    print("\n" + "="*80)
    print("Per-zone statistics complete!")
    print("="*80)

    # ===== Cumulative Improvement Analysis =====
    print(f"\n\nCUMULATIVE IMPROVEMENT ACROSS {len(successful_results)} SUCCESSFUL SCENES")
    print("="*80)

    # Calculate average improvements across all scenes
    mean_improvements = [imp['mean_improvement_dB'] for imp in improvement_summary]
    median_improvements = [imp['median_improvement_dB'] for imp in improvement_summary]
    p10_improvements = [imp['p10_improvement_dB'] for imp in improvement_summary]
    p90_improvements = [imp['p90_improvement_dB'] for imp in improvement_summary]

    print(f"\nMean Power Improvement:")
    print(f"  Average improvement:  {np.mean(mean_improvements):>+7.2f} dB")
    print(f"  Std dev:              {np.std(mean_improvements):>8.2f} dB")
    print(f"  Min improvement:      {np.min(mean_improvements):>+7.2f} dB ({improvement_summary[np.argmin(mean_improvements)]['scene_name']})")
    print(f"  Max improvement:      {np.max(mean_improvements):>+7.2f} dB ({improvement_summary[np.argmax(mean_improvements)]['scene_name']})")
    print(f"  Scenes improved:      {sum(1 for x in mean_improvements if x > 0)}/{len(successful_results)}")

    print(f"\nMedian Power Improvement:")
    print(f"  Average improvement:  {np.mean(median_improvements):>+7.2f} dB")
    print(f"  Std dev:              {np.std(median_improvements):>8.2f} dB")
    print(f"  Min improvement:      {np.min(median_improvements):>+7.2f} dB ({improvement_summary[np.argmin(median_improvements)]['scene_name']})")
    print(f"  Max improvement:      {np.max(median_improvements):>+7.2f} dB ({improvement_summary[np.argmax(median_improvements)]['scene_name']})")

    print(f"\n10th Percentile Improvement:")
    print(f"  Average improvement:  {np.mean(p10_improvements):>+7.2f} dB")

    print(f"\n90th Percentile Improvement:")
    print(f"  Average improvement:  {np.mean(p90_improvements):>+7.2f} dB")

    # ===== Aggregate Statistics Across All Cells =====
    print(f"\n\nAGGREGATE STATISTICS (All cells from {len(successful_results)} successful scenes)")
    print("="*80)

    # Collect all zone power values
    all_zone_power_initial = np.concatenate([data['zone_power_initial'] for data in successful_results.values()])
    all_zone_power_optimized = np.concatenate([data['zone_power_optimized'] for data in successful_results.values()])

    aggregate_initial = {
        'mean_power': np.mean(all_zone_power_initial),
        'median_power': np.median(all_zone_power_initial),
        'percentile_10': np.percentile(all_zone_power_initial, 10),
        'percentile_90': np.percentile(all_zone_power_initial, 90),
        'std_dev': np.std(all_zone_power_initial),
        'total_cells': len(all_zone_power_initial)
    }

    aggregate_optimized = {
        'mean_power': np.mean(all_zone_power_optimized),
        'median_power': np.median(all_zone_power_optimized),
        'percentile_10': np.percentile(all_zone_power_optimized, 10),
        'percentile_90': np.percentile(all_zone_power_optimized, 90),
        'std_dev': np.std(all_zone_power_optimized),
        'total_cells': len(all_zone_power_optimized)
    }

    print(f"\nINITIAL Configuration:")
    print(f"  Mean power:       {aggregate_initial['mean_power']:>8.2f} dBm")
    print(f"  Median power:     {aggregate_initial['median_power']:>8.2f} dBm")
    print(f"  10th percentile:  {aggregate_initial['percentile_10']:>8.2f} dBm")
    print(f"  90th percentile:  {aggregate_initial['percentile_90']:>8.2f} dBm")
    print(f"  Std deviation:    {aggregate_initial['std_dev']:>8.2f} dB")
    print(f"  Total cells:      {aggregate_initial['total_cells']:,}")

    print(f"\nOPTIMIZED Configuration:")
    print(f"  Mean power:       {aggregate_optimized['mean_power']:>8.2f} dBm")
    print(f"  Median power:     {aggregate_optimized['median_power']:>8.2f} dBm")
    print(f"  10th percentile:  {aggregate_optimized['percentile_10']:>8.2f} dBm")
    print(f"  90th percentile:  {aggregate_optimized['percentile_90']:>8.2f} dBm")
    print(f"  Std deviation:    {aggregate_optimized['std_dev']:>8.2f} dB")
    print(f"  Total cells:      {aggregate_optimized['total_cells']:,}")

    print(f"\nAGGREGATE IMPROVEMENT:")
    print(f"  Mean power:       {aggregate_optimized['mean_power'] - aggregate_initial['mean_power']:>+8.2f} dB")
    print(f"  Median power:     {aggregate_optimized['median_power'] - aggregate_initial['median_power']:>+8.2f} dB")
    print(f"  10th percentile:  {aggregate_optimized['percentile_10'] - aggregate_initial['percentile_10']:>+8.2f} dB")
    print(f"  90th percentile:  {aggregate_optimized['percentile_90'] - aggregate_initial['percentile_90']:>+8.2f} dB")

    # ===== Validation Statistics =====
    print(f"\n\nZONE VALIDATION STATISTICS")
    print("="*80)
    
    zone_attempts = [data['zone_attempts'] for data in successful_results.values()]
    percentile_ranges = [data['validation_stats']['percentile_range_db'] for data in successful_results.values()]
    p10_values = [data['validation_stats']['p10_power_dbm'] for data in successful_results.values()]
    p90_values = [data['validation_stats']['p90_power_dbm'] for data in successful_results.values()]
    
    print(f"\nZone Search Attempts:")
    print(f"  Mean attempts:    {np.mean(zone_attempts):.1f}")
    print(f"  Max attempts:     {np.max(zone_attempts)}")
    print(f"  Min attempts:     {np.min(zone_attempts)}")
    
    print(f"\nValidated Zone Characteristics:")
    print(f"  P10 (mean):           {np.mean(p10_values):.1f} dBm")
    print(f"  P10 (min):            {np.min(p10_values):.1f} dBm")
    print(f"  P10 (max):            {np.max(p10_values):.1f} dBm")
    print(f"  P90 (mean):           {np.mean(p90_values):.1f} dBm")
    print(f"  P90 (min):            {np.min(p90_values):.1f} dBm")
    print(f"  P90 (max):            {np.max(p90_values):.1f} dBm")
    print(f"  Percentile range (mean):  {np.mean(percentile_ranges):.1f} dB")
    print(f"  Percentile range (min):   {np.min(percentile_ranges):.1f} dB")
    print(f"  Percentile range (max):   {np.max(percentile_ranges):.1f} dB")

    # ===== CDF Comparison Plot =====
    print("\n\nGenerating CDF Comparison (Initial vs Optimized)")
    print("="*80)

    # Sort power values for CDF
    sorted_initial = np.sort(all_zone_power_initial)
    sorted_optimized = np.sort(all_zone_power_optimized)
    cdf = np.arange(1, len(sorted_initial) + 1) / len(sorted_initial)

    # Create comparison plot
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

    # CDF comparison
    ax1.plot(sorted_initial, cdf * 100, linewidth=2, label='Initial (Baseline)', alpha=0.7)
    ax1.plot(sorted_optimized, cdf * 100, linewidth=2, label='Optimized', alpha=0.7)
    ax1.axhline(y=50, color='gray', linestyle='--', alpha=0.3)
    ax1.axhline(y=10, color='red', linestyle='--', alpha=0.3)
    ax1.axhline(y=90, color='green', linestyle='--', alpha=0.3)
    ax1.set_xlabel('Signal Strength (dBm)', fontsize=12)
    ax1.set_ylabel('Cumulative Probability (%)', fontsize=12)
    ax1.set_title(f'CDF Comparison: Initial vs Optimized\n({len(successful_results)} Validated Scenes)', fontsize=14, fontweight='bold')
    ax1.grid(True, alpha=0.3)
    ax1.legend(loc='best', fontsize=11)

    # Improvement histogram
    ax2.hist(mean_improvements, bins=20, edgecolor='black', alpha=0.7)
    ax2.axvline(x=np.mean(mean_improvements), color='red', linestyle='--', linewidth=2, 
                label=f'Mean: {np.mean(mean_improvements):+.2f} dB')
    ax2.axvline(x=0, color='gray', linestyle='-', linewidth=1, alpha=0.5)
    ax2.set_xlabel('Mean Power Improvement (dB)', fontsize=12)
    ax2.set_ylabel('Number of Scenes', fontsize=12)
    ax2.set_title(f'Distribution of Improvements Across {len(successful_results)} Scenes', fontsize=14, fontweight='bold')
    ax2.grid(True, alpha=0.3, axis='y')
    ax2.legend(fontsize=11)

    plt.tight_layout()
    plt.show()

    print(f"\nAnalysis complete!")
    print(f"Median coverage in target zones improved by an average of {np.mean(median_improvements):+.2f} dB across {len(successful_results)} validated scenes.")
    print("="*80)
